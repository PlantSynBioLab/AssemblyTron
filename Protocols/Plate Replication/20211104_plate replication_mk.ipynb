# %%
import pandas as pd
import os

# %%
plasmids_df = pd.read_csv('WL_plasmids.csv')
plasmids_df = plasmids_df[['pWL','plate','row','col','bacterial res']]
plasmids_df = plasmids_df[(plasmids_df['plate'] == 1) | (plasmids_df['plate'] == 2)]


for i, row in plasmids_df.iterrows():
    if (plasmids_df.loc[i,'plate']) == 'Ampicillin':
        plasmids_df.loc[i,'plate'] = 'Amp'
        
for i, row in plasmids_df.iterrows():
    if (plasmids_df.loc[i,'plate']) == 'AMP/Chlor':
        plasmids_df.loc[i,'plate'] = 'AMP/Chl'
        
for i, row in plasmids_df.iterrows():
    if (plasmids_df.loc[i,'plate']) == 'Chloramphenicol':
        plasmids_df.loc[i,'plate'] = 'Chl'
        
        
plasmids_df['col'] = plasmids_df['col'].astype(int)

plasmids_df['loc'] = plasmids_df['row'] + plasmids_df['col'].astype(str)

plasmids_df
# Out:
#        pWL  plate row  col bacterial res loc
# 148  197.0    2.0   B    9           Amp  B9
# 149  196.0    2.0   B    8           Kan  B8
# 150  195.0    2.0   B    7           Amp  B7
# 151  194.0    2.0   B    6           Kan  B6
# 152  193.0    2.0   B    5           Amp  B5
# ..     ...    ...  ..  ...           ...  ..
# 339    6.0    1.0   A    5           Amp  A5
# 340    5.0    1.0   A    4           Amp  A4
# 341    3.0    1.0   A    3           Amp  A3
# 342    2.0    1.0   A    2           Amp  A2
# 343    1.0    1.0   A    1           Amp  A1
#
# [195 rows x 6 columns]

# %%
# plate 1 of plasmid
# Out:
#        pWL  plate row  col bacterial res loc
# 148  197.0    2.0   B    9           Amp  B9
# 149  196.0    2.0   B    8           Kan  B8
# 150  195.0    2.0   B    7           Amp  B7
# 151  194.0    2.0   B    6           Kan  B6
# 152  193.0    2.0   B    5           Amp  B5
# ..     ...    ...  ..  ...           ...  ..
# 339    6.0    1.0   A    5           Amp  A5
# 340    5.0    1.0   A    4           Amp  A4
# 341    3.0    1.0   A    3           Amp  A3
# 342    2.0    1.0   A    2           Amp  A2
# 343    1.0    1.0   A    1           Amp  A1
#
# [195 rows x 6 columns]

# %%
overnight_df = pd.read_csv('overnight.csv')
overnight_df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-bf1c899b2a80> in <module>
# ----> 1 overnight_df = pd.read_csv('overnight.csv')
#       2 overnight_df
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# ...
