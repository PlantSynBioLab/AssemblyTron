# %%
gibson= x
print(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-5d7ddc125637> in <module>
# ----> 1 gibson= x
#       2 print(x)
#
# NameError: name 'x' is not defined

# %% [markdown]
# #This is the first part of the gibson pseudocode
