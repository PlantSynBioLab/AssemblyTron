# %%
'protocolName': 'gibson_assembly',
'author':'Cameron Longmire <camel94@vt.edu>',
'description':'Pipette cleaning',
'apiLevel':'2.2'

# %% [markdown]
# #pipette cleaning protocol, Cameron Longmire, 11/9/21

# %%
#Load packages
from opentrons import protocol_api
from opentrons import simulate
protocol = simulate.get_protocol_api('2.2')

import pandas
import numpy as np
import os
import tkinter as tk
# Out:
# C:\Users\camdaman\.opentrons\robot_settings.json not found. Loading defaults
# C:\Users\camdaman\.opentrons\deck_calibration.json not found. Loading defaults

# %%
#Setting up tkinter window prompt for number of pipette tip boxes, tip size, and well location of boxes to clean

# %%
from tkinter import * 
window = Tk()
window.geometry("400x100")
window.title("Tip well count")

entry = Entry(window)
entry.pack()

def confirm():
    label = Label(window,text = entry.get())
    label.pack()
    global Wellcount
    Wellcount = entry.get()
   
    window.destroy()
button = Button(window,text="Enter number of pipette boxes to clean, from 1 to 3",command = confirm)
button.pack()



window.mainloop()
Wellcount
Wellcount = int(Wellcount)

# %%
if Wellcount > 0:
    from tkinter import * 
    window = Tk()
    window.geometry("400x100")
    window.title("Tip well count")

    entry = Entry(window)
    entry.pack()

    def confirm():
        label = Label(window,text = entry.get())
        label.pack()
        global Tipsize1
        Tipsize1 = entry.get()
   
        window.destroy()
    button = Button(window,text="Enter size of pipette tip box 1, in uL, either 10,300, or 1000 ",command = confirm)
    button.pack()



    window.mainloop()
if Wellcount > 1:
    from tkinter import * 
    window = Tk()
    window.geometry("400x100")
    window.title("Tip well count")

    entry = Entry(window)
    entry.pack()

    def confirm():
        label = Label(window,text = entry.get())
        label.pack()
        global Tipsize2
        Tipsize2 = entry.get()
   
        window.destroy()
    button = Button(window,text="Enter size of pipette tip box 2, in uL, either 10,300, or 1000 ",command = confirm)
    button.pack()



    window.mainloop()
if Wellcount > 2:
    from tkinter import * 
    window = Tk()
    window.geometry("400x100")
    window.title("Tip well count")

    entry = Entry(window)
    entry.pack()

    def confirm():
        label = Label(window,text = entry.get())
        label.pack()
        global Tipsize3
        Tipsize3 = entry.get()
   
        window.destroy()
    button = Button(window,text="Enter size of pipette tip box 3, in uL, either 10,300, or 1000 ",command = confirm)
    button.pack()



    window.mainloop()
# Out:
# '300'

# %%
if Wellcount > 0:
    from tkinter import * 
    window = Tk()
    window.geometry("400x100")
    window.title("Tip well 1 location")

    entry = Entry(window)
    entry.pack()

    def confirm():
        label = Label(window,text = entry.get())
        label.pack()
        global Location1
        Location1 = entry.get()
   
        window.destroy()
    button = Button(window,text="Enter location of Pipette tip box 1 ",command = confirm)
    button.pack()



    window.mainloop()
if Wellcount > 1:
    from tkinter import * 
    window = Tk()
    window.geometry("400x100")
    window.title("Tip well 2 Location")

    entry = Entry(window)
    entry.pack()

    def confirm():
        label = Label(window,text = entry.get())
        label.pack()
        global Location2
        Locatioin2 = entry.get()
   
        window.destroy()
    button = Button(window,text="Enter location of Pipette tip box 2",command = confirm)
    button.pack()



    window.mainloop()
if Wellcount > 2:
    from tkinter import * 
    window = Tk()
    window.geometry("400x100")
    window.title("Tip well 3 Location")

    entry = Entry(window)
    entry.pack()

    def confirm():
        label = Label(window,text = entry.get())
        label.pack()
        global Location3
        Location3 = entry.get()
   
        window.destroy()
    button = Button(window,text="Enter location of Pipette tip box 3",command = confirm)
    button.pack()



    window.mainloop()

# %%
#Have a tkinter prompt window that requests what pipette volume we will be cleaning and how many sets of that volume?

#Load Labware 
if Wellcount > 0:
    if Tipsize1 == '10':
        tiprack1 = protocol.load_labware('opentrons_96_tiprack_10ul',Location1)
    if Tipsize1 == '300':
        tiprack1 = protocol.load_labware('opentrons_96_tiprack_300ul',Location1)
    if Tipsize1 == '1000':
        tiprack1 = protocol.load_labware('opentrons_96_tiprack_1000ul',Location1)
if Wellcount > 1:
    if Tipsize2 == '10':
        tiprack2 = protocol.load_labware('opentrons_96_tiprack_10ul',Location2)
    if Tipsize2 == '300':
        tiprack2 = protocol.load_labware('opentrons_96_tiprack_300ul',Location2)
    if Tipsize2 == '1000':
        tiprack2 = protocol.load_labware('opentrons_96_tiprack_1000ul',Location2)
if Wellcount > 2:    
    if Tipsize3 == '10':
        tiprack3 = protocol.load_labware('opentrons_96_tiprack_10ul',Location3)
    if Tipsize3 == '300':
        tiprack3 = protocol.load_labware('opentrons_96_tiprack_300ul',Location3)
    if Tipsize3 == '1000':
        tiprack3 = protocol.load_labware('opentrons_96_tiprack_1000ul',Location3)
    
solutionrack = protocol.load_labware('opentrons_6_tuberack_falcon_50ml_conical',3)#verify location
left_pipette = protocol.load_instrument('p20_single_gen2','left') #gotta tie this in too
tiprack1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-6d0822228545> in <module>
#       5     tiprack1 = protocol.load_labware('opentrons_96_tiprack_10ul',Location1) #How to change 4 to location specified by Location1 value and how to modify the 20ul to Tipsizeul
#       6 if Tipsize == '300':
# ----> 7     tiprack1 = protocol.load_labware('opentrons_96_tiprack_300ul',Location1)#verify location
#       8 if Tipsize == '1000':
#       9     tiprack1 = protocol.load_labware('opentrons_96_tiprack_1000ul',Location1)#verify location
#
# ~\anaconda3\lib\site-packages\opentrons\protocols\api_support\util.py in _check_version_wrapper(*args, **kwargs)
#     389                     f'must increase your API version to {added_in} to '
#     390                     'use this functionality.')
# --> 391             return decorated_obj(*args, **kwargs)
#     392
# ...

# %%
#Can I turn off some parts of the process if we clean more than one or one type of tip? take input to clean multiple types of tips?

# %%
id2well = {}
id2well['0'] = 'A1'
id2well['1'] = 'A2'
id2well['2'] = 'A3'
id2well['3'] = 'A4'
id2well['4'] = 'A5'
id2well['5'] = 'A6'
id2well['6'] = 'A7'
id2well['7'] = 'A8'
id2well['8'] = 'A9'
id2well['9'] = 'A10'
id2well['10'] = 'A11'
id2well['11'] = 'A12'
id2well['12'] = 'B1'
id2well['13'] = 'B2'
id2well['14'] = 'B3'
id2well['15'] = 'B4'
id2well['16'] = 'B5'
id2well['17'] = 'B6'
id2well['18'] = 'B7'
id2well['19'] = 'B8'
id2well['20'] = 'B9'
id2well['21'] = 'B10'
id2well['22'] = 'B11'
id2well['23'] = 'B12'
id2well['24'] = 'C1'
id2well['25'] = 'C2'
id2well['26'] = 'C3'
id2well['27'] = 'C4'
id2well['28'] = 'C5'
id2well['29'] = 'C6'
id2well['30'] = 'C7'
id2well['31'] = 'C8'
id2well['32'] = 'C9'
id2well['33'] = 'C10'
id2well['34'] = 'C11'
id2well['35'] = 'C12'
id2well['36'] = 'D1'
id2well['37'] = 'D2'
id2well['38'] = 'D3'
id2well['39'] = 'D4'
id2well['40'] = 'D5'
id2well['41'] = 'D6'
id2well['42'] = 'D7'
id2well['43'] = 'D8'
id2well['44'] = 'D9'
id2well['45'] = 'D10'
id2well['46'] = 'D11'
id2well['47'] = 'D12'
id2well['48'] = 'E1'
id2well['49'] = 'E2'
id2well['50'] = 'E3'
id2well['51'] = 'E4'
id2well['52'] = 'E5'
id2well['53'] = 'E6'
id2well['54'] = 'E7'
id2well['55'] = 'E8'
id2well['56'] = 'E9'
id2well['57'] = 'E10'
id2well['58'] = 'E11'
id2well['59'] = 'E12'
id2well['60'] = 'F1'
id2well['61'] = 'F2'
id2well['62'] = 'F3'
id2well['63'] = 'F4'
id2well['64'] = 'F5'
id2well['65'] = 'F6'
id2well['66'] = 'F7'
id2well['67'] = 'F8'
id2well['68'] = 'F9'
id2well['69'] = 'F10'
id2well['70'] = 'F11'
id2well['71'] = 'F12'
id2well['72'] = 'G1'
id2well['73'] = 'G2'
id2well['74'] = 'G3'
id2well['75'] = 'G4'
id2well['76'] = 'G5'
id2well['77'] = 'G6'
id2well['78'] = 'G7'
id2well['79'] = 'G8'
id2well['80'] = 'G9'
id2well['81'] = 'G10'
id2well['82'] = 'G11'
id2well['83'] = 'G12'
id2well['84'] = 'H1'
id2well['85'] = 'H2'
id2well['86'] = 'H3'
id2well['87'] = 'H4'
id2well['88'] = 'H5'
id2well['89'] = 'H6'
id2well['90'] = 'H7'
id2well['91'] = 'H8'
id2well['92'] = 'H9'
id2well['93'] = 'H10'
id2well['94'] = 'H11'
id2well['95'] = 'H12'

#Protocol
r=0
if r > 96:
    left_pipette.pick_up_tip(tiprack1[id2well[r]])  #Help here? did this work?
    left_pipette.mix(3,20,solutionrack['A1'])
    left_pipette.blow_out()
    left_pipette.return_tip()
    r += 1
